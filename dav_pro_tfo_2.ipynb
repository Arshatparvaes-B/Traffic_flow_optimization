# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('TrafficDataset.csv', encoding='unicode_escape')
print(df)
# Out:
#             Timestamp          Location Weather  DayOfWeek    TimeOfDay  \
# 0    10-10-2023 08:00       City Center   Clear     Sunday      Morning
# 1    10-10-2023 08:15            Suburb   Rainy     Monday      Morning
# 2    10-10-2023 09:30   Industrial Area   Foggy    Tuesday  Mid-Morning
# 3    10-10-2023 12:45  Residential Area   Clear  Wednesday         Noon
# 4    10-10-2023 14:30          Downtown   Rainy   Thursday    Afternoon
# ..                ...               ...     ...        ...          ...
# 104  10-10-2023 12:45            Suburb   Rainy     Monday         Noon
# 105  10-10-2023 15:00  Residential Area   Clear    Tuesday    Afternoon
# 106  10-10-2023 17:15   Industrial Area   Foggy  Wednesday      Evening
# 107  10-10-2023 09:30          Downtown   Clear   Thursday  Mid-Morning
# 108  10-10-2023 11:45            Suburb   Clear     Monday         Noon
#
#      AverageSpeed  MaxSpeed  MinSpeed  TrafficVolume VehicleType  Accidents  \
# 0              40        60        30           1000         Car          2
# 1              30        50        20            800       Truck          1
# 2              20        45        15           1200     Bicycle          0
# 3              35        55        25            900  Motorcycle          0
# 4              25        45        20           1100         Car          1
# ..            ...       ...       ...            ...         ...        ...
# 104            30        50        25           1200         Car          0
# 105            45        65        35           1400         Car          0
# 106            20        40        15           1100       Truck          0
# 107            35        55        25           1000         Car          0
# 108            30        50        25           1200         Car          0
#
#     Construction PublicTransportation EnvironmentalConditions TravelTime  \
# 0             No                  Yes                Bus Stop     Normal
# 1            Yes                   No           Train Station       Poor
# 2             No                  Yes               Bike Lane     Normal
# 3             No                   No          Subway Station     Normal
# 4            Yes                  Yes               Tram Stop       Poor
# ..           ...                  ...                     ...        ...
# 104          Yes                   No                Bus Stop     Normal
# 105           No                   No               Tram Stop       Poor
# 106           No                  Yes           Train Station       Good
# 107          Yes                  Yes                Bus Stop     Normal
# 108          Yes                  Yes                Bus Stop       Poor
#
#      CO2Emissions  FuelConsumption  OptimizationStatus TravelerSatisfaction  \
# 0              25                5                  10            Optimized
# 1              30                8                  15        Not Optimized
# 2              40                2                   5            Optimized
# 3              20                3                   8            Optimized
# 4              35                6                  12        Not Optimized
# ..            ...              ...                 ...                  ...
# 104            33                6                  12            Optimized
# 105            22                8                  16        Not Optimized
# 106            25                5                  10            Optimized
# 107            30                7                  14        Not Optimized
# 108            35                6                  12            Optimized
#
#      Rating
# 0         4
# 1         2
# 2         5
# 3         4
# 4         3
# ..      ...
# 104       4
# 105       3
# 106       5
# 107       2
# 108       4
#
# [109 rows x 20 columns]

# %%
df.shape
# Out:
# (109, 20)

# %%
df.head()
# Out:
#           Timestamp          Location Weather  DayOfWeek    TimeOfDay  \
# 0  10-10-2023 08:00       City Center   Clear     Sunday      Morning
# 1  10-10-2023 08:15            Suburb   Rainy     Monday      Morning
# 2  10-10-2023 09:30   Industrial Area   Foggy    Tuesday  Mid-Morning
# 3  10-10-2023 12:45  Residential Area   Clear  Wednesday         Noon
# 4  10-10-2023 14:30          Downtown   Rainy   Thursday    Afternoon
#
#    AverageSpeed  MaxSpeed  MinSpeed  TrafficVolume VehicleType  Accidents  \
# 0            40        60        30           1000         Car          2
# 1            30        50        20            800       Truck          1
# 2            20        45        15           1200     Bicycle          0
# 3            35        55        25            900  Motorcycle          0
# 4            25        45        20           1100         Car          1
#
#   Construction PublicTransportation EnvironmentalConditions TravelTime  \
# 0           No                  Yes                Bus Stop     Normal
# 1          Yes                   No           Train Station       Poor
# 2           No                  Yes               Bike Lane     Normal
# 3           No                   No          Subway Station     Normal
# 4          Yes                  Yes               Tram Stop       Poor
#
#    CO2Emissions  FuelConsumption  OptimizationStatus TravelerSatisfaction  \
# 0            25                5                  10            Optimized
# 1            30                8                  15        Not Optimized
# 2            40                2                   5            Optimized
# 3            20                3                   8            Optimized
# 4            35                6                  12        Not Optimized
#
#    Rating
# 0       4
# 1       2
# 2       5
# 3       4
# 4       3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                109 non-null    object
#  1   Location                 109 non-null    object
#  2   Weather                  109 non-null    object
#  3   DayOfWeek                109 non-null    object
#  4   TimeOfDay                109 non-null    object
#  5   AverageSpeed             109 non-null    int64
#  6   MaxSpeed                 109 non-null    int64
#  7   MinSpeed                 109 non-null    int64
#  8   TrafficVolume            109 non-null    int64
#  9   VehicleType              109 non-null    object
#  10  Accidents                109 non-null    int64
#  11  Construction             109 non-null    object
#  12  PublicTransportation     109 non-null    object
#  13  EnvironmentalConditions  109 non-null    object
#  14  TravelTime               109 non-null    object
#  15  CO2Emissions             109 non-null    int64
#  16  FuelConsumption          109 non-null    int64
#  17  OptimizationStatus       109 non-null    int64
#  18  TravelerSatisfaction     109 non-null    object
#  19  Rating                   109 non-null    int64
# dtypes: int64(9), object(11)
# memory usage: 17.2+ KB

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     AverageSpeed  MaxSpeed  MinSpeed  TrafficVolume  \
# AverageSpeed            1.000000  0.998765  0.982554       0.796831
# MaxSpeed                0.998765  1.000000  0.981264       0.802705
# MinSpeed                0.982554  0.981264  1.000000       0.813948
# TrafficVolume           0.796831  0.802705  0.813948       1.000000
# Accidents               0.192211  0.190944  0.184940       0.178382
# CO2Emissions           -0.725086 -0.720606 -0.744183      -0.641861
# FuelConsumption         0.575194  0.571749  0.614124       0.465433
# OptimizationStatus      0.613775  0.610503  0.652499       0.496604
# Rating                 -0.121711 -0.114986 -0.105598      -0.055865
#
#                     Accidents  CO2Emissions  FuelConsumption  \
# AverageSpeed         0.192211     -0.725086         0.575194
# MaxSpeed             0.190944     -0.720606         0.571749
# MinSpeed             0.184940     -0.744183         0.614124
# TrafficVolume        0.178382     -0.641861         0.465433
# Accidents            1.000000     -0.257750         0.073379
# CO2Emissions        -0.257750      1.000000        -0.432390
# FuelConsumption      0.073379     -0.432390         1.000000
# OptimizationStatus   0.087265     -0.463844         0.996650
# Rating              -0.177656      0.125269        -0.049664
#
#                     OptimizationStatus    Rating
# AverageSpeed                  0.613775 -0.121711
# MaxSpeed                      0.610503 -0.114986
# MinSpeed                      0.652499 -0.105598
# TrafficVolume                 0.496604 -0.055865
# Accidents                     0.087265 -0.177656
# CO2Emissions                 -0.463844  0.125269
# FuelConsumption               0.996650 -0.049664
# OptimizationStatus            1.000000 -0.057819
# Rating                       -0.057819  1.000000

# %%
sb.histplot(df['TimeOfDay'],kde=True)
# Out:
# <Axes: xlabel='TimeOfDay', ylabel='Count'>

# %%
pl =sb.countplot(data= df, x= 'Weather')

for bars in pl.containers:
  pl.bar_label(bars)

# %%
sb.histplot(df['AverageSpeed'],kde=True)
# Out:
# <Axes: xlabel='AverageSpeed', ylabel='Count'>

# %%
sb.histplot(df['AverageSpeed'],kde=True)

# %%
sb.histplot(df['AverageSpeed'],kde=True)

# %%
sb.histplot(df['TrafficVolume'],kde=True)
# Out:
# <Axes: xlabel='TrafficVolume', ylabel='Count'>

# %%
sb.histplot(df['FuelConsumption'])
# Out:
# <Axes: xlabel='FuelConsumption', ylabel='Count'>

# %%
sb.histplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
df.corr()
# Out:
# <ipython-input-24-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     AverageSpeed  MaxSpeed  MinSpeed  TrafficVolume  \
# AverageSpeed            1.000000  0.998765  0.982554       0.796831
# MaxSpeed                0.998765  1.000000  0.981264       0.802705
# MinSpeed                0.982554  0.981264  1.000000       0.813948
# TrafficVolume           0.796831  0.802705  0.813948       1.000000
# Accidents               0.192211  0.190944  0.184940       0.178382
# CO2Emissions           -0.725086 -0.720606 -0.744183      -0.641861
# FuelConsumption         0.575194  0.571749  0.614124       0.465433
# OptimizationStatus      0.613775  0.610503  0.652499       0.496604
# Rating                 -0.121711 -0.114986 -0.105598      -0.055865
#
#                     Accidents  CO2Emissions  FuelConsumption  \
# AverageSpeed         0.192211     -0.725086         0.575194
# MaxSpeed             0.190944     -0.720606         0.571749
# MinSpeed             0.184940     -0.744183         0.614124
# TrafficVolume        0.178382     -0.641861         0.465433
# Accidents            1.000000     -0.257750         0.073379
# CO2Emissions        -0.257750      1.000000        -0.432390
# FuelConsumption      0.073379     -0.432390         1.000000
# OptimizationStatus   0.087265     -0.463844         0.996650
# Rating              -0.177656      0.125269        -0.049664
#
#                     OptimizationStatus    Rating
# AverageSpeed                  0.613775 -0.121711
# MaxSpeed                      0.610503 -0.114986
# MinSpeed                      0.652499 -0.105598
# TrafficVolume                 0.496604 -0.055865
# Accidents                     0.087265 -0.177656
# CO2Emissions                 -0.463844  0.125269
# FuelConsumption               0.996650 -0.049664
# OptimizationStatus            1.000000 -0.057819
# Rating                       -0.057819  1.000000

# %%
sb.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-25-a4d6a5eb07b4>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
df.Place.value_counts()

# %%
df.replace({'Yes':1,'No':0, 'Y':1, 'N':0, "YES":1},inplace=True)
df['TravelTime'] = df['TravelTime'].map({'poor': 0, 'Normal':1,'Good':2})
print(df)
# Out:
#             Timestamp          Location Weather  DayOfWeek    TimeOfDay  \
# 0    10-10-2023 08:00       City Center   Clear     Sunday      Morning
# 1    10-10-2023 08:15            Suburb   Rainy     Monday      Morning
# 2    10-10-2023 09:30   Industrial Area   Foggy    Tuesday  Mid-Morning
# 3    10-10-2023 12:45  Residential Area   Clear  Wednesday         Noon
# 4    10-10-2023 14:30          Downtown   Rainy   Thursday    Afternoon
# ..                ...               ...     ...        ...          ...
# 104  10-10-2023 12:45            Suburb   Rainy     Monday         Noon
# 105  10-10-2023 15:00  Residential Area   Clear    Tuesday    Afternoon
# 106  10-10-2023 17:15   Industrial Area   Foggy  Wednesday      Evening
# 107  10-10-2023 09:30          Downtown   Clear   Thursday  Mid-Morning
# 108  10-10-2023 11:45            Suburb   Clear     Monday         Noon
#
#      AverageSpeed  MaxSpeed  MinSpeed  TrafficVolume VehicleType  Accidents  \
# 0              40        60        30           1000         Car          2
# 1              30        50        20            800       Truck          1
# 2              20        45        15           1200     Bicycle          0
# 3              35        55        25            900  Motorcycle          0
# 4              25        45        20           1100         Car          1
# ..            ...       ...       ...            ...         ...        ...
# 104            30        50        25           1200         Car          0
# 105            45        65        35           1400         Car          0
# 106            20        40        15           1100       Truck          0
# 107            35        55        25           1000         Car          0
# 108            30        50        25           1200         Car          0
#
#      Construction  PublicTransportation EnvironmentalConditions  TravelTime  \
# 0               0                     1                Bus Stop         NaN
# 1               1                     0           Train Station         NaN
# 2               0                     1               Bike Lane         NaN
# 3               0                     0          Subway Station         NaN
# 4               1                     1               Tram Stop         NaN
# ..            ...                   ...                     ...         ...
# 104             1                     0                Bus Stop         NaN
# 105             0                     0               Tram Stop         NaN
# 106             0                     1           Train Station         NaN
# 107             1                     1                Bus Stop         NaN
# 108             1                     1                Bus Stop         NaN
#
#      CO2Emissions  FuelConsumption  OptimizationStatus TravelerSatisfaction  \
# 0              25                5                  10            Optimized
# 1              30                8                  15        Not Optimized
# 2              40                2                   5            Optimized
# 3              20                3                   8            Optimized
# 4              35                6                  12        Not Optimized
# ..            ...              ...                 ...                  ...
# 104            33                6                  12            Optimized
# 105            22                8                  16        Not Optimized
# 106            25                5                  10            Optimized
# 107            30                7                  14        Not Optimized
# 108            35                6                  12            Optimized
#
#      Rating
# 0         4
# 1         2
# 2         5
# 3         4
# 4         3
# ..      ...
# 104       4
# 105       3
# 106       5
# 107       2
# 108       4
#
# [109 rows x 20 columns]

# %% [markdown]
# <h2>Testing</h2>

# %%
from scipy.stats import shapiro  # Shapiro-Wilk test
from scipy.stats import probplot  # Q-Q plot
from scipy.stats import normaltest

# %%
from statsmodels.stats.weightstats import ztest as ztest

print("H0:There is no significant difference between sample mean and given mean.")
print("H1:There is significant difference between samples. ")

group1=df['TrafficVolume']
print("-----------------")
print("Width of Road:")
print(group1.describe())
print('-----------------')
z_stat1,p_value1=ztest(group1,value=100)

z_alpha=0.05
if p_value1<z_alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Accept the null hypothesis: There is no significant difference between the sample mean and given mean.")
# Out:
# H0:There is no significant difference between sample mean and given mean.
# H1:There is significant difference between samples.
# -----------------
# Width of Road:
# count     109.000000
# mean     1131.192661
# std       191.822279
# min       800.000000
# 25%      1000.000000
# 50%      1100.000000
# 75%      1300.000000
# max      1500.000000
# Name: TrafficVolume, dtype: float64
# -----------------
# Reject the null hypothesis: There is a significant difference between the means.

# %%
print("H0:There is no significant difference between means.")
print("H1:There is significant difference between means. ")
# Convert categorical variables to numerical values
df['TrafficVolume'] = df['Traffic_Volume'].astype('category').cat.codes
df['Rating'] = df['Rating'].astype('category').cat.codes

# Perform Z-test on the numerical versions
z_stat, p_value = ztest(df['Traffic_Volume'], df['Rating'])
# group1=df['Traffic_Density']
# group2=df['TIME']
# z_stat,p_value=ztest(group1,group2)

z_alpha=0.05

if p_value<z_alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Accept the null hypothesis: There is no significant difference between the means.")
# Out:
# H0:There is no significant difference between means.
# H1:There is significant difference between means.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Traffic_Volume'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-1c605bc57520> in <cell line: 4>()
#       2 print("H1:There is significant difference between means. ")
#       3 # Convert categorical variables to numerical values
# ----> 4 df['TrafficVolume'] = df['Traffic_Volume'].astype('category').cat.codes
#       5 df['Rating'] = df['Rating'].astype('category').cat.codes
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Traffic_Volume'
